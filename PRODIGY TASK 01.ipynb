# %% [markdown]
# # PRODIGY TASK 01

# %% [markdown]
# ### PROBLEM STATEMENT-
# ### Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable, such as the distribution of ages or genders in a population.

# %%
# Importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('https://raw.githubusercontent.com/aishwaryadatascience/PRODIGY-TASK-01/main/world_population.csv')

# %%
df.head()
# Out:
#          Series Name  Series Code    Country Name Country Code        2022  \
# 0  Population, total  SP.POP.TOTL     Afghanistan          AFG  41128771.0
# 1  Population, total  SP.POP.TOTL         Albania          ALB   2775634.0
# 2  Population, total  SP.POP.TOTL         Algeria          DZA  44903225.0
# 3  Population, total  SP.POP.TOTL  American Samoa          ASM     44273.0
# 4  Population, total  SP.POP.TOTL         Andorra          AND     79824.0
#
#          2021        2020        2019        2018        2017  ...  \
# 0  40099462.0  38972230.0  37769499.0  36686784.0  35643418.0  ...
# 1   2811666.0   2837849.0   2854191.0   2866376.0   2873457.0  ...
# 2  44177969.0  43451666.0  42705368.0  41927007.0  41136546.0  ...
# 3     45035.0     46189.0     47321.0     48424.0     49463.0  ...
# 4     79034.0     77700.0     76343.0     75013.0     73837.0  ...
#
#          2010        2009        2008        2007        2006        2005  \
# ...

# %%
df.tail()
# Out:
#                                    Series Name        Series Code  \
# 1080  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1081  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1082  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1083  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
# 1084  Population, male (% of total population)  SP.POP.TOTL.MA.ZS
#
#                Country Name Country Code       2022       2021       2020  \
# 1080  Virgin Islands (U.S.)          VIR  46.613382  46.764444  46.914637
# 1081     West Bank and Gaza          PSE  49.893678  49.877839  49.858957
# 1082            Yemen, Rep.          YEM  50.519031  50.538516  50.554317
# 1083                 Zambia          ZMB  49.344602  49.344951  49.338301
# 1084               Zimbabwe          ZWE  47.214139  47.167153  47.130679
#
#            2019       2018       2017  ...       2010       2009       2008  \
# ...

# %%
df.shape
# Out:
# (1085, 26)

# %%
df.columns
# Out:
# Index(['Series Name', 'Series Code', 'Country Name', 'Country Code', '2022',
#        '2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013',
#        '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004',
#        '2003', '2002', '2001'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1085 entries, 0 to 1084
# Data columns (total 26 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Series Name   1085 non-null   object
#  1   Series Code   1085 non-null   object
#  2   Country Name  1085 non-null   object
#  3   Country Code  1085 non-null   object
#  4   2022          1085 non-null   float64
#  5   2021          1085 non-null   float64
#  6   2020          1085 non-null   float64
#  7   2019          1085 non-null   float64
#  8   2018          1085 non-null   float64
#  9   2017          1085 non-null   float64
#  10  2016          1085 non-null   float64
#  11  2015          1085 non-null   float64
#  12  2014          1085 non-null   float64
#  13  2013          1085 non-null   float64
#  14  2012          1085 non-null   float64
#  15  2011          1085 non-null   float64
#  16  2010          1085 non-null   float64
# ...

# %%
df.describe()
# Out:
#                2022          2021          2020          2019          2018  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.461378e+07  1.449711e+07  1.437307e+07  1.422876e+07  1.407966e+07
# std    7.832944e+07  7.801505e+07  7.763257e+07  7.712985e+07  7.657562e+07
# min    2.749000e+01  2.732503e+01  2.735104e+01  2.676295e+01  2.573928e+01
# 25%    5.034029e+01  5.035172e+01  5.034171e+01  5.033040e+01  5.033917e+01
# 50%    1.465500e+05  1.463660e+05  1.461650e+05  1.459570e+05  1.457520e+05
# 75%    5.903468e+06  5.856733e+06  5.831404e+06  5.814422e+06  5.774185e+06
# max    1.417173e+09  1.412360e+09  1.411100e+09  1.407745e+09  1.402760e+09
#
#                2017          2016          2015          2014          2013  \
# count  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03  1.085000e+03
# mean   1.392568e+07  1.376711e+07  1.360705e+07  1.344625e+07  1.328368e+07
# ...

# %% [markdown]
# ## Checking for Duplicate rows

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Checking for Missing values

# %%
df.isna().sum()
# Out:
# Series Name     0
# Series Code     0
# Country Name    0
# Country Code    0
# 2022            0
# 2021            0
# 2020            0
# 2019            0
# 2018            0
# 2017            0
# 2016            0
# 2015            0
# 2014            0
# 2013            0
# 2012            0
# 2011            0
# 2010            0
# 2009            0
# 2008            0
# 2007            0
# 2006            0
# 2005            0
# 2004            0
# 2003            0
# 2002            0
# 2001            0
# dtype: int64

# %% [markdown]
# ### Checking for unique values

# %%
print(df['Country Name'].unique())
print("\nTotal no of Unique Countries:", df['Country Name'].nunique())
# Out:
# ['Afghanistan' 'Albania' 'Algeria' 'American Samoa' 'Andorra' 'Angola'
#  'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba' 'Australia' 'Austria'
#  'Azerbaijan' 'Bahamas, The' 'Bahrain' 'Bangladesh' 'Barbados' 'Belarus'
#  'Belgium' 'Belize' 'Benin' 'Bermuda' 'Bhutan' 'Bolivia'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei Darussalam' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cabo Verde'
#  'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands'
#  'Central African Republic' 'Chad' 'Channel Islands' 'Chile' 'China'
#  'Colombia' 'Comoros' 'Congo, Dem. Rep.' 'Congo, Rep.' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia' 'Denmark'
#  'Djibouti' 'Dominica' 'Dominican Republic' 'Ecuador' 'Egypt, Arab Rep.'
#  'El Salvador' 'Equatorial Guinea' 'Eritrea' 'Estonia' 'Eswatini'
#  'Ethiopia' 'Faroe Islands' 'Fiji' 'Finland' 'France' 'French Polynesia'
#  'Gabon' 'Gambia, The' 'Georgia' 'Germany' 'Ghana' 'Gibraltar' 'Greece'
# ...

# %%
print(df['Country Code'].unique())
print("\nTotal no of Unique Country Code:", df['Country Code'].nunique())
# Out:
# ['AFG' 'ALB' 'DZA' 'ASM' 'AND' 'AGO' 'ATG' 'ARG' 'ARM' 'ABW' 'AUS' 'AUT'
#  'AZE' 'BHS' 'BHR' 'BGD' 'BRB' 'BLR' 'BEL' 'BLZ' 'BEN' 'BMU' 'BTN' 'BOL'
#  'BIH' 'BWA' 'BRA' 'VGB' 'BRN' 'BGR' 'BFA' 'BDI' 'CPV' 'KHM' 'CMR' 'CAN'
#  'CYM' 'CAF' 'TCD' 'CHI' 'CHL' 'CHN' 'COL' 'COM' 'COD' 'COG' 'CRI' 'CIV'
#  'HRV' 'CUB' 'CUW' 'CYP' 'CZE' 'DNK' 'DJI' 'DMA' 'DOM' 'ECU' 'EGY' 'SLV'
#  'GNQ' 'ERI' 'EST' 'SWZ' 'ETH' 'FRO' 'FJI' 'FIN' 'FRA' 'PYF' 'GAB' 'GMB'
#  'GEO' 'DEU' 'GHA' 'GIB' 'GRC' 'GRL' 'GRD' 'GUM' 'GTM' 'GIN' 'GNB' 'GUY'
#  'HTI' 'HND' 'HKG' 'HUN' 'ISL' 'IND' 'IDN' 'IRN' 'IRQ' 'IRL' 'IMN' 'ISR'
#  'ITA' 'JAM' 'JPN' 'JOR' 'KAZ' 'KEN' 'KIR' 'PRK' 'KOR' 'XKX' 'KWT' 'KGZ'
#  'LAO' 'LVA' 'LBN' 'LSO' 'LBR' 'LBY' 'LIE' 'LTU' 'LUX' 'MAC' 'MDG' 'MWI'
#  'MYS' 'MDV' 'MLI' 'MLT' 'MHL' 'MRT' 'MUS' 'MEX' 'FSM' 'MDA' 'MCO' 'MNG'
#  'MNE' 'MAR' 'MOZ' 'MMR' 'NAM' 'NRU' 'NPL' 'NLD' 'NCL' 'NZL' 'NIC' 'NER'
#  'NGA' 'MKD' 'MNP' 'NOR' 'OMN' 'PAK' 'PLW' 'PAN' 'PNG' 'PRY' 'PER' 'PHL'
# ...

# %%
df['Series Name'].unique()
# Out:
# array(['Population, total', 'Population, female', 'Population, male',
#        'Population, female (% of total population)',
#        'Population, male (% of total population)'], dtype=object)

# %%
df['Series Code'].unique()
# Out:
# array(['SP.POP.TOTL', 'SP.POP.TOTL.FE.IN', 'SP.POP.TOTL.MA.IN',
#        'SP.POP.TOTL.FE.ZS', 'SP.POP.TOTL.MA.ZS'], dtype=object)

# %% [markdown]
# ## Dropping unnecessary columns

# %%
df.drop(['Series Name', 'Country Code'], axis=1, inplace= True)
df.columns
# Out:
# Index(['Series Code', 'Country Name', '2022', '2021', '2020', '2019', '2018',
#        '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009',
#        '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001'],
#       dtype='object')

# %% [markdown]
# ## Extraction of Top 10 Countries

# %%
# Filter data for Total Population
total_population= df[df['Series Code'] == 'SP.POP.TOTL']

# Sorting the data based on 2022 population
total_population_sorted= total_population.sort_values(by= "2022", ascending= False)

# Getting the Top 10 Countries with highest 2022 population
top_ten_countries= total_population_sorted.head(10)
print("Top 10 Countries of Total Population\n")
print(top_ten_countries[['Country Name']])
# Out:
# Top 10 Countries of Total Population
#
#            Country Name
# 89                India
# 41                China
# 206       United States
# 90            Indonesia
# 149            Pakistan
# 144             Nigeria
# 26               Brazil
# 15           Bangladesh
# 161  Russian Federation
# 127              Mexico

# %% [markdown]
# ## Top 10 Countries of Total Population in the Year 2022 and 2016

# %%
# Creating Bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x= "2022", y= "Country Name", data= top_ten_countries, palette= "coolwarm")
plt.title("Top 10 Countries of Total Population 2022", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

plt.figure(figsize= (15,6))
plt.subplot(2,2,2)
sns.barplot(x= "2016", y= "Country Name", data= top_ten_countries, palette= "coolwarm")
plt.title("Top 10 Countries of Total Population 2016", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

# %% [markdown]
# ## Top 10 Countries of Total Population in the Year 2010 and 2001

# %%
# Creating Bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x= "2010", y= "Country Name", data= top_ten_countries, palette= "coolwarm")
plt.title("Top 10 Countries of Total Population 2010", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

plt.figure(figsize= (15,6))
plt.subplot(2,2,2)
sns.barplot(x= "2001", y= "Country Name", data= top_ten_countries, palette= "coolwarm")
plt.title("Top 10 Countries of Total Population 2001", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

# %% [markdown]
# ## Extraction of Bottom 10 Countries

# %%
# Sorting Data 
total_population_sorted1= total_population.sort_values(by= "2022", ascending= True)

# Getting the bottom 10 Countries
bottom_ten= total_population_sorted1.head(10)
print("Bottom 10 Countries of Total Population\n")
print(bottom_ten[["Country Name"]])
# Out:
# Bottom 10 Countries of Total Population
#
#                  Country Name
# 201                    Tuvalu
# 137                     Nauru
# 150                     Palau
# 27     British Virgin Islands
# 183  St. Martin (French part)
# 75                  Gibraltar
# 164                San Marino
# 130                    Monaco
# 114             Liechtenstein
# 124          Marshall Islands

# %% [markdown]
# ## Bottom 10 Countries of Total Population in the Year 2022 and 2016

# %%
# Creating Bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x= "2022", y= "Country Name", data= bottom_ten, palette= "coolwarm")
plt.title("Bottom 10 Countries of Total Population 2022", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

plt.figure(figsize= (15,6))
plt.subplot(2,2,2)
sns.barplot(x= "2016", y= "Country Name", data= bottom_ten, palette= "coolwarm")
plt.title("Bottom 10 Countries of Total Population 2016", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

# %% [markdown]
# ## Bottom 10 Countries of Total Population in the Year 2010 and 2001

# %%
# Creating Bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x= "2010", y= "Country Name", data= bottom_ten, palette= "coolwarm")
plt.title("Bottom 10 Countries of Total Population 2010", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

plt.figure(figsize= (15,6))
plt.subplot(2,2,2)
sns.barplot(x= "2001", y= "Country Name", data= bottom_ten, palette= "coolwarm")
plt.title("Bottom 10 Countries of Total Population 2001", fontsize= 10)
plt.xlabel("Total Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

# %% [markdown]
# ## Extraction of Top 10 Countries with Highest Male Population

# %%
# Filter data for Male Population
male_population= df[df['Series Code'] == 'SP.POP.TOTL.MA.IN']

# Sorting the data based on 2022 male population
male_population_sorted= male_population.sort_values(by= "2022", ascending= False)

# Getting the Top 10 Countries with highest 2022 male population
male_ten_countries= male_population_sorted.head(10)
print("Top 10 Countries of Male Population")
print(male_ten_countries[['Country Name']])
# Out:
# Top 10 Countries of Male Population
#            Country Name
# 523               India
# 475               China
# 640       United States
# 524           Indonesia
# 583            Pakistan
# 578             Nigeria
# 460              Brazil
# 449          Bangladesh
# 595  Russian Federation
# 561              Mexico

# %% [markdown]
# ## Extraction of Top 10 Countries with Highest Female Population

# %%
# Filter data for Male Population
female_population= df[df['Series Code'] == 'SP.POP.TOTL.FE.IN']

# Sorting the data based on 2022 Female population
female_population_sorted= female_population.sort_values(by= "2022", ascending= False)

# Getting the Top 10 Countries with highest 2022 Female population
female_ten_countries= female_population_sorted.head(10)
print("Top 10 Countries of Female Population")
print(female_ten_countries[['Country Name']])
# Out:
# Top 10 Countries of Female Population
#            Country Name
# 258               China
# 306               India
# 423       United States
# 307           Indonesia
# 366            Pakistan
# 243              Brazil
# 361             Nigeria
# 232          Bangladesh
# 378  Russian Federation
# 344              Mexico

# %% [markdown]
# ## Top 10 Countries of Highest Male and Female Population in 2022

# %%
# Creating Bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x= "2022", y= "Country Name", data= male_ten_countries, palette= "viridis")
plt.title("Top 10 Countries of Highest Male Population 2022", fontsize= 10)
plt.xlabel("Male Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

plt.figure(figsize= (15,6))
plt.subplot(2,2,2)
sns.barplot(x= "2016", y= "Country Name", data= female_ten_countries, palette= "viridis")
plt.title("Top 10 Countries of Highest Female Population 2016", fontsize= 10)
plt.xlabel("Female Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

# %% [markdown]
# ## Extraction of Top 10 Countries with Lowest Male Population

# %%
lowest_male= male_population_sorted.tail(10)
print("Top 10 Countries of Lowest Male Population")
print(lowest_male[["Country Name"]])
# Out:
# Top 10 Countries of Lowest Male Population
#                  Country Name
# 558          Marshall Islands
# 548             Liechtenstein
# 564                    Monaco
# 598                San Marino
# 509                 Gibraltar
# 617  St. Martin (French part)
# 461    British Virgin Islands
# 584                     Palau
# 571                     Nauru
# 635                    Tuvalu

# %% [markdown]
# ## Extraction of Top 10 Countries with Lowest Female Population

# %%
lowest_female= female_population_sorted.tail(10)
print("Top 10 Countries of Lowest Female Population")
print(lowest_female[["Country Name"]])
# Out:
# Top 10 Countries of Lowest Female Population
#                   Country Name
# 389  Sint Maarten (Dutch part)
# 331              Liechtenstein
# 347                     Monaco
# 381                 San Marino
# 400   St. Martin (French part)
# 292                  Gibraltar
# 244     British Virgin Islands
# 367                      Palau
# 354                      Nauru
# 418                     Tuvalu

# %% [markdown]
# ## Top 10 Countries with Lowest Male amd Female Population in 2022

# %%
# Creating Bar plot
plt.figure(figsize=(15,6))
plt.subplot(2,2,1)
sns.barplot(x= "2022", y= "Country Name", data= lowest_male, palette= "viridis")
plt.title("Top 10 Countries of Lowest Male Population 2022", fontsize= 10)
plt.xlabel("Male Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

plt.figure(figsize= (15,6))
plt.subplot(2,2,2)
sns.barplot(x= "2022", y= "Country Name", data= lowest_female, palette= "viridis")
plt.title("Top 10 Countries of Lowest Female Population 2022", fontsize= 10)
plt.xlabel("Female Population", fontsize= 10)
plt.ylabel("Country", fontsize= 10)
plt.show()

# %% [markdown]
# ## STACKED BARPLOT

# %% [markdown]
# ## Top 10 Countries with Male and Female Population 2022

# %%
# Merging male and female population
merged_data= pd.merge(male_population, female_population, on= "Country Name", suffixes= ("_male", "_female"))

# %%
merged_data
# Out:
#       Series Code_male           Country Name   2022_male   2021_male  \
# 0    SP.POP.TOTL.MA.IN            Afghanistan  20766442.0  20254878.0
# 1    SP.POP.TOTL.MA.IN                Albania   1384548.0   1404454.0
# 2    SP.POP.TOTL.MA.IN                Algeria  22862237.0  22497244.0
# 3    SP.POP.TOTL.MA.IN         American Samoa     21873.0     22289.0
# 4    SP.POP.TOTL.MA.IN                Andorra     40786.0     40361.0
# ..                 ...                    ...         ...         ...
# 212  SP.POP.TOTL.MA.IN  Virgin Islands (U.S.)     49137.0     49510.0
# 213  SP.POP.TOTL.MA.IN     West Bank and Gaza   2516444.0   2455361.0
# 214  SP.POP.TOTL.MA.IN            Yemen, Rep.  17023203.0  16668432.0
# 215  SP.POP.TOTL.MA.IN                 Zambia   9877642.0   9609004.0
# 216  SP.POP.TOTL.MA.IN               Zimbabwe   7705601.0   7543690.0
#
#       2020_male   2019_male   2018_male   2017_male   2016_male   2015_male  \
# ...

# %%
# Calculating total population for each country
merged_data["Total Population"]= merged_data["2022_male"] + merged_data["2022_female"]

# %%
merged_data.head()
# Out:
#     Series Code_male    Country Name   2022_male   2021_male   2020_male  \
# 0  SP.POP.TOTL.MA.IN     Afghanistan  20766442.0  20254878.0  19692301.0
# 1  SP.POP.TOTL.MA.IN         Albania   1384548.0   1404454.0   1419264.0
# 2  SP.POP.TOTL.MA.IN         Algeria  22862237.0  22497244.0  22132899.0
# 3  SP.POP.TOTL.MA.IN  American Samoa     21873.0     22289.0     22921.0
# 4  SP.POP.TOTL.MA.IN         Andorra     40786.0     40361.0     39615.0
#
#     2019_male   2018_male   2017_male   2016_male   2015_male  ...  \
# 0  19090409.0  18549862.0  18028696.0  17520861.0  17071446.0  ...
# 1   1428828.0   1435881.0   1440219.0   1442176.0   1444890.0  ...
# 2  21756903.0  21362603.0  20961313.0  20556314.0  20152232.0  ...
# 3     23535.0     24134.0     24701.0     25240.0     25739.0  ...
# 4     38842.0     38071.0     37380.0     36628.0     36188.0  ...
#
#    2009_female  2008_female  2007_female  2006_female  2005_female  \
# ...

# %%
# Sorting data in descending order
sorted_data= merged_data.sort_values(by= "Total Population", ascending= False)

# Selecting top 10 countries
top_10_countries= sorted_data.head(10)

# %%
# Creating Stacked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x= "Country Name", y= "2022_female", data= top_10_countries, color= "red", label= "Female Population")
sns.barplot(x= "Country Name", y= "2022_male", data= top_10_countries, bottom= top_10_countries["2022_female"], color= "blue", label= "Male Population")
plt.title("Top 10 Countries with Male & Female Population 2022")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha= "right")
plt.show()

# %% [markdown]
# ## Bottom 10 Countries

# %%
# Selecting bottom 10 Countries
bottom_10_countries= sorted_data.tail(10)

# %%
# Creating Stacked bar plot
plt.figure(figsize=(12,6))
sns.barplot(x= "Country Name", y= "2022_female", data= bottom_10_countries, color= "red", label= "Female Population")
sns.barplot(x= "Country Name", y= "2022_male", data= bottom_10_countries, bottom= bottom_10_countries["2022_female"], color= "blue", label= "Male Population")
plt.title("Bottom 10 Countries with Male & Female Population 2022")
plt.xlabel("Country")
plt.ylabel("Population")
plt.legend()
plt.xticks(rotation=45, ha= "right")
plt.show()
